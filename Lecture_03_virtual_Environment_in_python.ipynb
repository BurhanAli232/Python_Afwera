# %% [markdown]
# <a href="https://colab.research.google.com/github/BurhanAli232/Python_Afwera/blob/main/Lecture_03_virtual_Environment_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Why we need the virtual environmet
# - Beacuse the reason when i want to install same library but two different version .So when we work on multiple project then we need virtual environment beacuse if the we use virtual environment then the project may occur the conflict.so we use virtual environment .Beacuse it is poosible we use one version for other project and the other version for another project that's the one reason

# %% [markdown]
# # what is virtual environment ?
# - A virtual environment is an isolated workspace in Python that allows you to manage dependencies for different projects separately. Each virtual environment has its own Python interpreter and installed packages, ensuring that projects do not interfere with each other.

# %% [markdown]
# # step 1
# - open search bar or simple press the window button and type "anaconda"
# - open the "anaconda prompt"![image_2025-04-17_175315162.png](data:image/png;base64,...)

# %% [markdown]
# # step 2
# - the open the CLI which is called commond line interface
# -If you already have dir then go to specific and create but if not then simple when you open the CLI types commonds and create environment![image_2025-04-17_180323489.png](data:image/png;base64,...)

# %% [markdown]
# # bouns tip
# - id your dir name is too much long then you type some letter after press 'tab' button then hole dir show

# %% [markdown]
# # step 3 ( start create environment )
# - This is the sntax of anaconda for create environment
#               conda create -n <environment_name> python=<version>
# -  now let's types the correct commond
#               conda create -n burhan_environment python=3.10
# -  This is first commond to create the environment when you types and press the enter button then some of file start downloading but firstly ask you want to install if yes then start if you type no then terminate the downloading file
# - after type 'Y'(YES) then wait some time until fil is not complete download
# - If you have internet issue dont worry you simple start downloading and drik energy drink if not complete now then you explore your notes like DL,MLPython etc

# %% [markdown]
# - some of time the open new CLI then you types the commond for create environment after type 'Y' then file download start and you wait until the environment is create sucessfuly
# - So wait
#                     Stay Positive really one day you will be shine just need to consistent
#                     Remember your dreams and your parents
# - Congrats your environment is create it mean can do this Motivate yourself and give some reward then continue

# %% [markdown]
# ![32.png](data:image/png;base64,...)

# %% [markdown]
# # step 4
# - Now need to Activated the conda environment
# - the syntax is:
#         conda activate environment_Name
# - when you run this commond the conda environment is create

# %% [markdown]
# ![image_2025-04-18_034651170.png](data:image/png;base64,...)

# %% [markdown]
# # Special note
# - when the environment is sucessfuly then the base convert to the environment name
#   - like in this case first line you can see base is display within brackets but after activate the environment the base is convert into the afwera beacuse my environment name is afwera
