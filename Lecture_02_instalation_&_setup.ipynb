# %% [markdown]
# <a href="https://colab.research.google.com/github/BurhanAli232/Python_Afwera/blob/main/Lecture_02_instalation_%26_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalation & setup
# - The step of is to install some software | or create a environment where you start the code so lets start to instalation.

# %% [markdown]
# # Step 1
# - Open the browser and simple type "download miniconda!![1.png](data:image/png;base64,...)

# %% [markdown]
# # Step 2
# - You can downloand the miniconda by click on download button or you can open the link ![2.png](data:image/png;base64,...)

# %% [markdown]
# # Step 3
# - You can simple click the skip registration
# - If you want to registration simple type email and press submit button after chect E-mail box .In this E-Mail link send to you and you can donwnload the miniconda ![3.png](data:image/png;base64,...)

# %% [markdown]
# # step 4
# - If you use the window simplw click the button for downloand the miniconda or if you use another operating system then you can select the oprating system which you use
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# # step 5
# - After downloand Button then the miniconda downloading will start
# - Wait for downloading the Minicoda until download you drink a water and a take some rest
# - Your health is more important so if you are heatly then you work more affectively
# - Programming is not important if your health is not Good | First responsibility to focus on your health![5.png](data:image/png;base64,...)![5(2).png](data:image/png;base64,...)

# %% [markdown]
# # step 6
# - After that press window key and type anaconda prompt(For checking the python is already install in our sytem or not)
# - When you open then Type "python -V" or "python --version"
# - The mostly python istall when i download mini anaconda But if not install Simple open Google type "Python download for window" then open first website also download the version which version you required
# - If the python version not display it mean the mini conda not correctly install you need to again intall the anaconda
# ![13.PNG](data:image/png;base64,...)![13(2).png](data:image/png;base64,...)

# %% [markdown]
# # step 6
# - After that you need to install a IDE
# - *IDE:*An IDE(Integrated development Environment) is a software suite that consolidate basic tool for software development
# - There are many IDE but we are download the most commonly to used also easy to use that name is "VS Code"

# %% [markdown]
# - Open the Google and type "VS code download"
# - when you open the first website then display you can download the vs code according to your need for Woindow or you can download other oprating system
# - After when we click it then the downloading again start
# - Now again need to drink a water or energy drink until the vs code download
#     - if you have internet problem then choos a best network according to your area if problem still then you folow these all step at 3AM
#
# ![16.png](data:image/png;base64,...)![15.png](data:image/png;base64,...)![14.png](data:image/png;base64,...)

# %% [markdown]
# # Step 7
# - After downloading you need to install
# - Now click on installed software then accept all the permission also press next until instalation is start just like mini conda instalation ![17.png](data:image/png;base64,...)

# %% [markdown]
# ![18.PNG](data:image/png;base64,...)

# %% [markdown]
# # step 8
# - Now after instaltation open the vs code
# - click on welcome go to the next location where you create a new folder or open exiting folder
# ![19.png](data:image/png;base64,...)

# %% [markdown]
# - Click on folder option you can create also open the folder which is already create
# ![20.PNG](data:image/png;base64,...)

# %% [markdown]
# - After creat folder VS code want permission then allow and press enter ![21.PNG](data:image/png;base64,...)

# %% [markdown]
# - After create folder you need to create a file where you write a code
# - simple click on file create button also the you can select any name of python file but extention must be ".py" example "python.py"![22.png](data:image/png;base64,...)

# %% [markdown]
# - Now when you type program line and after that you want to run but the run opein is disable until you not install extention simple click on install button ![23.png](data:image/png;base64,...)

# %% [markdown]
# - if the option not show the click extention button and download the python extention ![24.png](data:image/png;base64,...)

# %% [markdown]
# ![25.PNG](data:image/png;base64,...)

# %% [markdown]
# - After that that the program run open is visible on top of screen ![26.png](data:image/png;base64,...)

# %% [markdown]
# - After maybe one error you
# - you simple select the python interpretor then this error will be resolved ![27.PNG](data:image/png;base64,...)

# %% [markdown]
# - when the interpreter select then you can show on your screen![28.png](data:image/png;base64,...)

# %% [markdown]
# - Now again click on run button Your program is successfuly run ![29.PNG](data:image/png;base64,...)

# %% [markdown]
# - Now you need 5-10 mint rest
# - drink a water and motivate yourself you can do it
# - just you required work hard then InshAllah one day you will be shine

# %% [markdown]
# - If you have any error then contact me by e-mail:burhanali0145@gmail.com

# %% [markdown]
# - Burhan update
